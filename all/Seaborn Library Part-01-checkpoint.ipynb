# %% [markdown]
# # Seaborn Library
#
# Seaborn is a library for making statistical graphics in pyhton

# %% [raw]
# There are some libraries that must be installed before using Seaborn .Here we will list out
# 1- Python 3.6
# 2- Numyp(>=1.13.3)
# 3- Scipy(>=0.22.0)
# 4- Pandas(>=0.22.0)
# 5- matplotlib(>=2.1.2)

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
var = [1,2,3,5,7,8]
var1 =[8,9,6,5,3,5]

# %% [markdown]
# # matplotlib

# %%
plt.plot(var,var1)
plt.show()

# %%
var = [1,2,3,5,7,8]
var1 =[8,9,6,5,3,5]

# %% [markdown]
# # Seaborn

# %%
sns.lineplot(x=var, y=var1)
plt.show()

# %%
var = [1,2,3,5,7,8]
var1 =[8,9,6,5,3,5]

import pandas as pd

# %%
df = pd.DataFrame({"var" : var ,"var1" : var1})
sns.lineplot(x='var', y= 'var1'  ,data = df)
plt.show()

# %%
df
# Out:
#    var  var1
# 0    1     8
# 1    2     9
# 2    3     6
# 3    5     5
# 4    7     3
# 5    8     5

# %%
df1 = sns.load_dataset("penguins")

# %%
df1
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.lineplot(x = "bill_length_mm" , y = "flipper_length_mm" , data = df1 , hue = "sex")
plt.show()

# %%
sns.lineplot(x = "bill_length_mm" , y = "flipper_length_mm" , data = df1 , hue = "sex" , palette= "rocket_r")
plt.show()

# %%
sns.lineplot(x = "bill_length_mm" , y = "flipper_length_mm" , data = df1 , hue = "sex", markers =["o",">"] )
plt.show()
